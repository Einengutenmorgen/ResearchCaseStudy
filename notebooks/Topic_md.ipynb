# %%
import pickle

import pandas as pd

path = '/Users/mogen/Desktop/Research/sampleoutputwithtoxandpol.pkl'
df= pd.read_pickle(path)

df
# Out:
#                                                 full_text  topics_num  \
# 0       @mrnygiants19 @CaseyDeSantis One whole month! ...          -1
# 1       State Offices Closed Tuesday, February 16 - mo...          -1
# 2       🚨😉 EL ROJO ESTÁ CHISTOSO❗️\n\n😎 Chicana a Raci...           3
# 3           Weather forecast this week: \n\nConsequences.          27
# 4                              @ShadoWoman888 Thank you 🥰          21
# ...                                                   ...         ...
# 599995  How Retailers Should Start Catering to Hybrid-...          -1
# 599996  I explained why France 🇫🇷 is burning today. Vi...          -1
# 599997  🚨NEW: Vivek Ramaswamy said he wants to go EVEN...          -1
# 599998  @Uniallure I just always know if I wanna fuck ...          -1
# 599999  On Inside the Hive, @brianstelter breaks down ...           1
#
#        toxicity_label  toxicity_score political_label  political_score  \
# ...

# %%
for row in df:
    if str(row['orginal_user_id'])=='18254098.0':
        print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 for row in df:
# ----> 2     if str(row['orginal_user_id'])=='18254098.0':
#       3         print(row)
#
# TypeError: string indices must be integers

# %%
df=df[df.original_user_id =='18254098.0' ]
df
# Out:
# Empty DataFrame
# Columns: [full_text, topics_num, toxicity_label, toxicity_score, political_label, political_score, topic_keywords, original_user_id]
# Index: []
